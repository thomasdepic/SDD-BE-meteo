# %% [markdown]
# Import des librairies :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Getting an inventory of csv available

# %%
# hardcoded directories
data_dir = "./data/"
mesures_dir =  data_dir + "mesures/"

# get a list of csv files
station_csv = data_dir + "stations.csv"
mesures_csvs = [mesures_dir + mes for mes in os.listdir(mesures_dir)]
n_mesures = len(mesures_csvs)

# %%
# explore a measure file
k_mesure = np.random.randint(0, n_mesures)
chosen_mesure = pd.read_csv(mesures_csvs[k_mesure])
print(f"Chosen station {mesures_csvs[k_mesure][-8:-4]} ({k_mesure}th listed station) in file {mesures_csvs[k_mesure]}\n")
print(chosen_mesure.head())
# Out:
# Chosen station 7015 (55th listed station) in file ./data/mesures/station_7015.csv
#
#                         Date  Pression au niveau mer  \
# 0  2017-01-15T13:00:00+01:00                102280.0
# 1  2017-10-10T02:00:00+02:00                101700.0
# 2  2017-10-21T23:00:00+02:00                101000.0
# 3  2017-04-16T20:00:00+02:00                102120.0
# 4  2018-04-13T23:00:00+02:00                101380.0
#
#    Variation de pression en 3 heures  Type de tendance barométrique  \
# 0                              -50.0                            8.0
# 1                             -100.0                            6.0
# 2                                0.0                            0.0
# 3                              -40.0                            6.0
# 4                              210.0                            3.0
#
#    Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  Température  \
# 0                          270.0                          3.3       276.15
# 1                          220.0                          4.1       286.75
# 2                          200.0                          9.1       284.15
# 3                          280.0                          6.0       285.15
# 4                          350.0                          2.7       283.65
#
#    Point de rosée  Humidité  Visibilité horizontale  ...  \
# 0          274.65      90.0                 15680.0  ...
# 1          285.35      91.0                 12250.0  ...
# 2          279.25      72.0                 60000.0  ...
# 3          276.35      55.0                 37560.0  ...
# 4          281.45      86.0                  4890.0  ...
#
#                      Type de tendance barométrique.1  Temps passé 1.1  \
# 0  Stationnaire ou en hausse, puis en baisse, ou ...              NaN
# 1  En baisse, puis stationnaire, ou en baisse, pu...              NaN
# 2  En hausse, puis en baisse la pression atmosphé...              NaN
# 3  En baisse, puis stationnaire, ou en baisse, pu...              NaN
# 4  En baisse ou stationnaire, puis en hausse, ou ...              NaN
#
#                                      Temps présent.1  Température (°C)  \
# 0  Pluie, sans congélation, continue, faible au m...               3.0
# 1  On n’a pas observé d’évolution des nuages ou o...              13.6
# 2  On n’a pas observé d’évolution des nuages ou o...              11.0
# 3  On n’a pas observé d’évolution des nuages ou o...              12.0
# 4                                              Brume              10.5
#
#    Température minimale sur 12 heures (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      6.2
# 4                                      NaN
#
#    Température minimale sur 24 heures (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Température maximale sur 12 heures (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     14.1
# 4                                      NaN
#
#    Température maximale sur 24 heures (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Température minimale du sol sur 12 heures (en °C)  mois_de_l_annee
# 0                                               -0.4                1
# 1                                               12.8               10
# 2                                                9.2               10
# 3                                                7.9                4
# 4                                               10.4                4
#
# [5 rows x 68 columns]
# Index(['Date', 'Pression au niveau mer', 'Variation de pression en 3 heures',
#        'Type de tendance barométrique', 'Direction du vent moyen 10 mn',
#        'Vitesse du vent moyen 10 mn', 'Température', 'Point de rosée',
#        'Humidité', 'Visibilité horizontale', 'Temps présent', 'Temps passé 1',
#        'Temps passé 2', 'Nebulosité totale',
#        'Nébulosité  des nuages de l' étage inférieur',
#        'Hauteur de la base des nuages de l'étage inférieur',
#        'Type des nuages de l'étage inférieur',
#        'Type des nuages de l'étage moyen',
#        'Type des nuages de l'étage supérieur', 'Pression station',
#        'Niveau barométrique', 'Géopotentiel',
#        'Variation de pression en 24 heures',
#        'Température minimale sur 12 heures',
#        'Température minimale sur 24 heures',
#        'Température maximale sur 12 heures',
#        'Température maximale sur 24 heures',
#        'Température minimale du sol sur 12 heures',
#        'Méthode de mesure Température du thermomètre mouillé',
#        'Température du thermomètre mouillé',
#        'Rafale sur les 10 dernières minutes', 'Rafales sur une période',
#        'Periode de mesure de la rafale', 'Etat du sol',
#        'Hauteur totale de la couche de neige, glace, autre au sol',
#        'Hauteur de la neige fraîche', 'Periode de mesure de la neige fraiche',
#        'Précipitations dans la dernière heure',
#        'Précipitations dans les 3 dernières heures',
#        'Précipitations dans les 6 dernières heures',
#        'Précipitations dans les 12 dernières heures',
#        'Précipitations dans les 24 dernières heures', 'Phénomène spécial 1',
#        'Phénomène spécial 2', 'Phénomène spécial 3', 'Phénomène spécial 4',
#        'Nébulosité couche nuageuse 1', 'Type nuage 1', 'Hauteur de base 1',
#        'Nébulosité couche nuageuse 2', 'Type nuage 2', 'Hauteur de base 2',
#        'Nébulosité couche nuageuse 3', 'Type nuage 3', 'Hauteur de base 3',
#        'Nébulosité couche nuageuse 4', 'Type nuage 4', 'Hauteur de base 4',
#        'Type de tendance barométrique.1', 'Temps passé 1.1', 'Temps présent.1',
#        'Température (°C)', 'Température minimale sur 12 heures (°C)',
#        'Température minimale sur 24 heures (°C)',
#        'Température maximale sur 12 heures (°C)',
#        'Température maximale sur 24 heures (°C)',
#        'Température minimale du sol sur 12 heures (en °C)', 'mois_de_l_annee'],
#       dtype='object')

# %%
for c in chosen_mesure.columns:
    print(c)
    print(chosen_mesure[c][3])
# Out:
# Date
# 2017-04-16T20:00:00+02:00
# Pression au niveau mer
# 102120.0
# Variation de pression en 3 heures
# -40.0
# Type de tendance barométrique
# 6.0
# Direction du vent moyen 10 mn
# 280.0
# Vitesse du vent moyen 10 mn
# 6.0
# Température
# 285.15
# Point de rosée
# 276.35
# Humidité
# 55.0
# Visibilité horizontale
# 37560.0
# Temps présent
# 0.0
# Temps passé 1
# nan
# Temps passé 2
# nan
# Nebulosité totale
# 100.0
# Nébulosité  des nuages de l' étage inférieur
# 8.0
# Hauteur de la base des nuages de l'étage inférieur
# 1250.0
# Type des nuages de l'étage inférieur
# nan
# Type des nuages de l'étage moyen
# nan
# Type des nuages de l'étage supérieur
# nan
# Pression station
# 101550.0
# Niveau barométrique
# nan
# Géopotentiel
# nan
# Variation de pression en 24 heures
# 240.0
# Température minimale sur 12 heures
# 279.35
# Température minimale sur 24 heures
# nan
# Température maximale sur 12 heures
# 287.25
# Température maximale sur 24 heures
# nan
# Température minimale du sol sur 12 heures
# 281.05
# Méthode de mesure Température du thermomètre mouillé
# nan
# Température du thermomètre mouillé
# nan
# Rafale sur les 10 dernières minutes
# 8.8
# Rafales sur une période
# 8.8
# Periode de mesure de la rafale
# -10.0
# Etat du sol
# 0.0
# Hauteur totale de la couche de neige, glace, autre au sol
# 0.0
# Hauteur de la neige fraîche
# nan
# Periode de mesure de la neige fraiche
# nan
# Précipitations dans la dernière heure
# 0.0
# Précipitations dans les 3 dernières heures
# 0.0
# Précipitations dans les 6 dernières heures
# 0.0
# Précipitations dans les 12 dernières heures
# 0.0
# Précipitations dans les 24 dernières heures
# 0.0
# Phénomène spécial 1
# nan
# Phénomène spécial 2
# nan
# Phénomène spécial 3
# nan
# Phénomène spécial 4
# nan
# Nébulosité couche nuageuse 1
# 2.0
# Type nuage 1
# nan
# Hauteur de base 1
# 1170.0
# Nébulosité couche nuageuse 2
# 4.0
# Type nuage 2
# nan
# Hauteur de base 2
# 1500.0
# Nébulosité couche nuageuse 3
# 8.0
# Type nuage 3
# nan
# Hauteur de base 3
# 1860.0
# Nébulosité couche nuageuse 4
# nan
# Type nuage 4
# nan
# Hauteur de base 4
# nan
# Type de tendance barométrique.1
# En baisse, puis stationnaire, ou en baisse, puis en baisse plus lente
# Temps passé 1.1
# nan
# Temps présent.1
# On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution
# Température (°C)
# 12.0
# Température minimale sur 12 heures (°C)
# 6.2000000000000455
# Température minimale sur 24 heures (°C)
# nan
# Température maximale sur 12 heures (°C)
# 14.100000000000025
# Température maximale sur 24 heures (°C)
# nan
# Température minimale du sol sur 12 heures (en °C)
# 7.900000000000034
# mois_de_l_annee
# 4
